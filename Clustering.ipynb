# %% [markdown]
# <a href="https://colab.research.google.com/github/remre/striveschool/blob/main/Clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Clustering**
# Hierarchical CLustering and K- Means Clustering

# %% [markdown]
# ##**Hierarchical Clustering**
#
# Agglomerative HC and Divisive HC
#
# ###Agglomerative HC
#
# Steps;
#
# 1- make each data point a single point cluster(That forms N clusters)
#
# 2-Take the two closest data points and make them one cluster(that forms n-1)
#
# 3-take two closests clusters adn  make them one cluster(that forms n-2)
#
# 4-repeat step 3 until there is only one cluster

# %%
import pandas as pd
import numpy as np

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from scipy.cluster.hierarchy import linkage, dendrogram as sch
import scipy.cluster.hierarchy as sch# it is unsuffficient to call library to times
import matplotlib.pyplot as plt

# %%
#load your data
mergins = sch.linkage(x, 'complete')#complete is the method

# %%
dn = sch.dendrogram(mergins, leaf_rotation = 90, leaf_font_size=6)#dendogram is like below 
plt.show()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ###**K-Means Clustering**
#
# steps;
#
#
# 1.   choose the number K of clusters
# 2.   select at random K points, the centroids(not necessariyl from your dataset)
# 3.   Assign each data point the closeset centroid
# 4.   Compute and place the new centroid of each cluster
# 5.   Reassign each data point to the new closest centroid. If any reassignment took place, go to step 4, otherwise finish it

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
#load your data set with  pd. read_csv() blabla
#make your values features = df.values[] u can choose X values (the features)
model = KMeans(n_clusters=3, init='k-means++', n_init=100, max_iter=1000)
# Fit to the data and predict the cluster assignments for each data point
km_clusters = model.fit_predict(features.values)#(this is the name of your groups or how cluster label them)

# %%
#plot it (plotting is depending on your number of features if it is more than 2 it is not possible to draw it in 2D)
f, (ax1, ax2) = plt.subplots(1, 2,figsize=(15,8))
ax1.set_title('K Means')
ax1.scatter(points[:,0],points[:,1],c=labels,cmap='autumn')
ax2.set_title("Original")
ax2.scatter(points[:,0],points[:,1])
ax1.grid()
ax2.grid()
